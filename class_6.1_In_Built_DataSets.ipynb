# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.simplefilter('ignore')

# %%
age=[4, 17, 7, 14, 18, 12, 3, 16, 10, 4, 4, 11]
sns.boxplot(age)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('iris')
df.head()

sns.boxplot( y=df["sepal_length"] );
plt.show()

# %%
df=pd.read_excel('ml_result_a.xlsx')
df.head()
# Out:
#           ID                    Name CT1 CT2 CT3  Assignment  MidTerm  \
# 0  180201002      MD. SHADMAN SHAKIB  18  27  27           7       28
# 1  180201003         MD. MIRAJ HOSEN   A  15  10           7       14
# 2  180201004   MD. MEHEDI HASAN RAJU   A   8   9           7       12
# 3  180201005    S. M. SHAKIB HOSSAIN   A  25  13           7       34
# 4  180201006  MD. FORHAD HOSEN FEROZ  10  15   9          10       21
#
#    Attendence  PartA PartB Grade  GPA
# 0          12     78    43    A-  3.5
# 1          13      0    17     F  0.0
# 2          13      2    24     F  0.0
# 3          13     53    51     B  3.0
# 4          13     19    20     F  0.0

# %%
b=[0,20,40,60,80,100]
l=['Non-coligiate','Fail','Average','good','Excellent']

# %%
df['Judgement']=pd.cut(df['PartA'],bins=b,labels=l)
#df

# %%
b=[0.00, 2.00,3.00, 3.50,4.00]
#l=['Fail','Average','good','Excellent']
l=['0.00-1.99', '2.00-2.99','3.00-3.49','3.50-4.00']
#b=[0,15,30,45]
#l=['0-15','16-30','31-45']

# %%
df['g_label']=pd.cut(df['GPA'],bins=b,labels=l,ordered=False)
df
# Out:
#            ID                             Name CT1 CT2   CT3  Assignment  \
# 0   180201002               MD. SHADMAN SHAKIB  18  27    27           7
# 1   180201003                  MD. MIRAJ HOSEN   A  15    10           7
# 2   180201004            MD. MEHEDI HASAN RAJU   A   8     9           7
# 3   180201005             S. M. SHAKIB HOSSAIN   A  25    13           7
# 4   180201006           MD. FORHAD HOSEN FEROZ  10  15     9          10
# 5   180201007                KAZI NISHAT ISLAM  12  10     2          10
# 6   180201010          CHANDRIKA SHEKHAR OISHI  17  24     A           8
# 7   180201011                    MAISHA RAIYAN   7  20    11          10
# 8   180201012          MD. AMINUL AHASAN PIAUS   0  15     7           8
# 9   180201015                 MD. ASIF HOSSAIN  18  27    27          12
# 10  180201016                     FAHMIDA FIZA  18  16    15          10
# 11  180201017                KANIZ FATIMA DAYA  26  25    17          10
# ...
