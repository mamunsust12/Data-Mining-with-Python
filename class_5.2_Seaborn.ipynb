# %% [markdown]
# # Seaborn:
# Python's Statistical Data Visualization Library uses Matplotlib underneath to plot graphs.
#
# It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
#warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
import seaborn as sns
sns.load_dataset
#sns.get_dataset_names()
# Out:
# <function seaborn.utils.load_dataset(name, cache=True, data_home=None, **kws)>

# %%
# Load iris data
iris = sns.load_dataset("iris")
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# to_excel : Write DataFrame to an Excel file.
#
# read_csv : Load a CSV file into a DataFrame.

# %%
iris.to_csv('iris_dataset.csv', index=False) 
data = pd.read_csv("iris_dataset.csv")
#print(data.head())

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load iris data
iris = sns.load_dataset("iris")
#iris = pd.read_csv("out.csv")
#print(iris.head())

# Construct iris plot
sns.swarmplot(x="species", y="petal_length", data=iris)

# Show plot
plt.show()

# %%
sns.swarmplot(x="sepal_length", y="petal_length", data=iris, hue="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
compression_opts = dict(method='zip', archive_name='zipped_out.csv')  
iris.to_csv('zipped_out.zip', index=False,compression=compression_opts)

# %% [markdown]
# # Seaborn - Data Visualization with titanic dataset

# %%
titanic=pd.read_csv('titanic/train.csv')
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# Count Plot

# %%
#sns.countplot(x='Survived',data=titanic)
sns.countplot(x='Survived', hue='Sex', data=titanic)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Sex',data=titanic)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Pclass',data=titanic)
#sns.countplot(x='Pclass',hue='Sex', data=titanic)
#sns.countplot(x='Pclass',hue='Survived', data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
#plt.plot(x='Pclass',y='Age',data=titanic)

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic['Age_group']=pd.cut(titanic.age, bins=[0,5,20,40,60,100], labels=['0-5','5-20','20-40','40-60','60-100'])
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df_new = titanic[['sex', 'age','Age_group']]
print(df_new.to_string())
# Out:
#         sex    age Age_group
# 0      male  22.00     20-40
# 1    female  38.00     20-40
# 2    female  26.00     20-40
# 3    female  35.00     20-40
# 4      male  35.00     20-40
# 5      male    NaN       NaN
# 6      male  54.00     40-60
# 7      male   2.00       0-5
# 8    female  27.00     20-40
# 9    female  14.00      5-20
# 10   female   4.00       0-5
# 11   female  58.00     40-60
# 12     male  20.00      5-20
# 13     male  39.00     20-40
# 14   female  14.00      5-20
# 15   female  55.00     40-60
# 16     male   2.00       0-5
# 17     male    NaN       NaN
# 18   female  31.00     20-40
# 19   female    NaN       NaN
# 20     male  35.00     20-40
# 21     male  34.00     20-40
# 22   female  15.00      5-20
# 23     male  28.00     20-40
# 24   female   8.00      5-20
# 25   female  38.00     20-40
# 26     male    NaN       NaN
# 27     male  19.00      5-20
# 28   female    NaN       NaN
# 29     male    NaN       NaN
# 30     male  40.00     20-40
# ...

# %%
df_new = titanic.iloc[:, [2,3,15]]
df_new
# Out:
#         sex   age Age_group
# 0      male  22.0     20-40
# 1    female  38.0     20-40
# 2    female  26.0     20-40
# 3    female  35.0     20-40
# 4      male  35.0     20-40
# ..      ...   ...       ...
# 886    male  27.0     20-40
# 887  female  19.0      5-20
# 888  female   NaN       NaN
# 889    male  26.0     20-40
# 890    male  32.0     20-40
#
# [891 rows x 3 columns]

# %%
#sns.countplot(x='Pclass',data=titanic)
sns.countplot(x='Age_group',hue='sex', data=df_new)
# Out:
# <AxesSubplot:xlabel='Age_group', ylabel='count'>

# %% [markdown]
# # Swarm plot

# %%
sns.swarmplot(x='Pclass',y='Age',data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.swarmplot(x="Sex", y="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.stripplot(x="Sex", y="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# Box Plot

# %%
sns.boxplot(x='Sex',y='Age',data=titanic)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x='Pclass',y='Age',data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x='Survived',y='Age', data=titanic)
#sns.boxplot(x='Survived',y='Age', hue='Sex', data=titanic)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %% [markdown]
# Violinplot

# %%
sns.violinplot(x="Survived", y="Age", data=titanic)
#sns.violinplot(x="Survived", y="Age", hue='Sex', data=titanic)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %% [markdown]
# Barplot

# %%
#sns.barplot(x="Survived", y="Age", data=titanic)
sns.barplot(x="Survived", y="Age",  hue='Sex', data=titanic)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.barplot(x="Survived", y="Age", data=titanic, palette='rocket')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %% [markdown]
# Heatmap

# %%
tc = titanic.corr()
sns.heatmap(tc,cmap='coolwarm')
plt.title('Titanic corellation Heatmap: titanic.corr()')
# Out:
# Text(0.5, 1.0, 'Titanic corellation Heatmap: titanic.corr()')

# %% [markdown]
# Pie Plot

# %%
# importing libraries
import matplotlib.pyplot as plt
import seaborn
  
# declaring data
data = [44, 45, 40, 41, 39]
keys = ['Class 1', 'Class 2', 'CLass 3', 'Class 4', 'Class 5']
  
# define Seaborn color palette to use
palette_color = seaborn.color_palette('bright')
  
# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')
  
# displaying chart
plt.show()
