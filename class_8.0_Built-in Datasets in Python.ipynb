# %% [markdown]
# # Built-in Datasets in Python

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Sklearn Datasets

# %%
from sklearn import datasets
#print(datasets)
#dir(datasets)

# %%
from sklearn.datasets import load_iris

# Load Iris data (https://en.wikipedia.org/wiki/Iris_flower_data_set)
dataset = load_iris()
#dataset

# %%
# Load iris into a dataframe and set the field names
df = pd.DataFrame(dataset['data'], columns=dataset['feature_names'])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
from PIL import Image
#img = Image.open("iris.jpg") 
img = Image.open(r"C:\Users\BAUST CSE\Desktop\Python\G1\Class 8 - Data Pre-Processing\iris.jpg")
img.show()

# %%
from skimage import io
img = io.imread("iris.jpg")
io.imshow(img)

# %%
df.shape
# Out:
# (150, 4)

# %%
df['class']=dataset['target']
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df.shape
# Out:
# (150, 5)

# %%
#df.to_csv('iris_1.csv')
df.to_csv('iris.csv', index=False)

# %%
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %% [markdown]
# # Data Attributes
#
# The main attributes of the datasets that you need to be aware of are:
#
# DESCR: to get a comprehensive description of the dataset
#
# data: to fetch the data of independent variables (features)
#
# target: to fetch the target variable
#
# feature_names: to get the names of features
#
# target_names: to get the names of target classes (target field name in case of regression data)

# %%
#print(datasets.load_wine().DESCR)
#print(datasets.load_wine().data)
#print(datasets.load_wine().target)
#print(datasets.load_wine().feature_names)
#print(datasets.load_wine().target_names)

# %%
print(datasets.load_wine().data)

# %%
print(datasets.load_wine().target)

# %%
print(datasets.load_wine().feature_names)

# %%
print(datasets.load_wine().target_names)

# %%
from sklearn import datasets
import pandas as pd
wine_data = pd.DataFrame(datasets.load_wine().data)
wine_data.columns = datasets.load_wine().feature_names
wine_data.head(5)

# %%
wine_data.to_csv('wine_data.csv')

# %%
import os
os.listdir()

# %% [markdown]
# # Seaborn Datasets

# %%
import seaborn as sns
sns.load_dataset
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset("iris")
iris
#print(type(iris))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
titanic = sns.load_dataset("titanic")
titanic.age

# %%
titanic.describe()

# %% [markdown]
# # Statsmodels Datasets

# %%
from statsmodels import datasets
#dir(datasets)

# %%
heart=datasets.heart.load_pandas().data
heart.head()

# %%
cancer=datasets.cancer.load_pandas().data
cancer.head()

# %% [markdown]
# # Vega-Datasets

# %%
#!pip install vega_datasets

# %%
#import vega_datasets
from vega_datasets import data
df = data.iris()
df.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
#data.list_datasets()

# %%
import pandas as pd

file_name = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
df = pd.read_csv(file_name)
df.head()
